# %%
from load_music import get_song_names, load_song
from segment import segment_onset
# import extract_features
import librosa
import numpy as np
import IPython.display as ipd

# %% [markdown]
# # Give a directory, get all the songs that are valid in there

# %%
songs = get_song_names(directory="/Users/benjamindykstra/Music/iTunes/Against Me!/")

# %%
songs
# Out:
# ['/Users/benjamindykstra/Music/iTunes/Against Me!/As The Eternal Cowboy/01 T.S.R. (This Shit Rules).m4a',
#  '/Users/benjamindykstra/Music/iTunes/Against Me!/As The Eternal Cowboy/02 Cliche Guevara.m4a',
#  '/Users/benjamindykstra/Music/iTunes/Against Me!/As The Eternal Cowboy/03 Mutiny On The Electronic Bay.m4a',
#  '/Users/benjamindykstra/Music/iTunes/Against Me!/As The Eternal Cowboy/04 Sink, Florida, Sink.m4a',
#  '/Users/benjamindykstra/Music/iTunes/Against Me!/As The Eternal Cowboy/05 Slurring The Rhythms.m4a',
#  '/Users/benjamindykstra/Music/iTunes/Against Me!/As The Eternal Cowboy/06 Rice And Bread.m4a',
#  '/Users/benjamindykstra/Music/iTunes/Against Me!/As The Eternal Cowboy/07 A Brief Yet Triumphant Intermissi.m4a',
#  '/Users/benjamindykstra/Music/iTunes/Against Me!/As The Eternal Cowboy/08 Unsubstantiated Rumors Are Good E.m4a',
#  '/Users/benjamindykstra/Music/iTunes/Against Me!/As The Eternal Cowboy/09 You Look Like I Need A Drink.m4a',
#  '/Users/benjamindykstra/Music/iTunes/Against Me!/As The Eternal Cowboy/10 Turn Those Clapping Hands Into An.m4a',
#  '/Users/benjamindykstra/Music/iTunes/Against Me!/As The Eternal Cowboy/11 Cavalier Eternal.m4a',
#  '/Users/benjamindykstra/Music/iTunes/Against Me!/New Wave/03 Thrash Unreal.m4a',
#  '/Users/benjamindykstra/Music/iTunes/Against Me!/New Wave/06 Borne On the FM Waves of the Hear.m4a',
#  '/Users/benjamindykstra/Music/iTunes/Against Me!/Reinventing Axl Rose/01 Pints of Guinness Make You Strong.m4a',
#  '/Users/benjamindykstra/Music/iTunes/Against Me!/Reinventing Axl Rose/04 I Still Love You Julie.m4a',
#  "/Users/benjamindykstra/Music/iTunes/Against Me!/Reinventing Axl Rose/09 Baby, I'm an Anarchist!.m4a",
#  '/Users/benjamindykstra/Music/iTunes/Against Me!/Reinventing Axl Rose/10 Walking Is Still Honest.m4a',
#  "/Users/benjamindykstra/Music/iTunes/Against Me!/Searching for a Former Clarity/13 Don't Lose Touch.m4a"]

# %% [markdown]
# # given a list of song file paths, load each song and segment it according to its onset. Shape of final list is (number of songs, ). For each song, shape is (number of segments in song, ). For each segment, shape is (number of audio samples in segment)

# %%
accum = []
for song in songs:
    signal, sr = load_song(song)
    onset_segmented = segment_onset(signal, sr, 512)
    print onset_segmented['shape']
    accum.append(onset_segmented['segmented'])
    
all_songs = np.array(accum)
print 'shape of all songs: {}'.format(all_songs.shape)
# Out:
# (161,)
# (201,)
# (141,)
# (508,)
# (453,)
# (333,)
# (349,)
# (422,)
# (269,)
# (655,)
# (671,)
# (609,)
# (820,)
# (656,)
# (770,)
# (522,)
# (407,)
# (472,)
# shape of all songs: (18,)

# %% [markdown]
# sanity check that if we concatenate all the segments in a song, it should be equal in length to the original signal

# %%
original_signal, sr = load_song(songs[-1])
onset_segmented = segment_onset(original_signal)
data = onset_segmented['segmented']
print data.shape, original_signal.shape

print "difference in shapes: {}".format(original_signal.shape[0] - np.concatenate(data).shape[0])
# Out:
# (472,) (3863748,)
# difference in shapes: 0

# %% [markdown]
# concatenate the first 10 segments of the first song and play it

# %%
first_ten = np.concatenate(all_songs[0][:10])

# %%
ipd.Audio(first_ten, rate=sr)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
ipd.Audio(np.concatenate(all_songs[0][:4]), rate=sr)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
ipd.Audio(np.concatenate(all_songs[0][:5]), rate=sr)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
ipd.Audio(np.concatenate(all_songs[0][4:6]), rate=sr)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
def mfcc(segment, sr=22050, n_mfcc=20):
    components = librosa.feature.mfcc(y=segment,sr=sr, n_mfcc=n_mfcc ) # 
    return np.mean(components[1:], axis=1)

# %%
def zero_crossing_rate(segment):
    rate_vector = librosa.feature.zero_crossing_rate(segment+ 0.0001, frame_length=len(segment))[0] # returns array with shape (1,x)
    return np.mean(rate_vector)

# %%
def avg_spectral_centroid(segment):
    '''
    Indicate at which frequency the energy is centered on. Like a weighted mean, weighting avg frequency by the energy.
    '''
    centroid = librosa.feature.spectral_centroid(segment+0.01, sr=sr, n_fft=len(segment))[0]
    return np.mean(centroid)

# %%
def avg_spectral_contrast(segment, sr=22050, n_bands=6):
    '''
    considers the spectral peak, the spectral valley, and their difference in each frequency subband
    
    columns correspond to a spectral band
    
    average contrast : np.ndarray [shape=(n_bands + 1)]
    each row of spectral contrast values corresponds to a given
    octave-based frequency, take average across bands
    
    '''
    contr = librosa.feature.spectral_contrast(segment, sr=sr, n_fft=len(segment) n_bands=n_bands)
    return np.mean(contr, axis=1) # take average across bands

# %%
def get_features(segment):
    if len(segment) != 0:
        feature_tuple = (avg_energy(segment), avg_mfcc(segment), zero_crossing_rate(segment), avg_spectral_centroid(segment), avg_spectral_contrast(segment))
        all_features = np.concatenate([feat if type(feat) is np.ndarray else np.array([feat]) for feat in feature_tuple])
        return all_features
    return np.zeros((29,))


def avg_energy(segment):
    if len(segment) != 0:
        energy = librosa.feature.rmse(y=segment, frame_length = len(segment))[0]
        # returns (1,t) array, get first element
        return np.mean(energy)

    
def avg_mfcc(segment, sr=22050, n_mfcc=20):
    '''
    Get the average Mel-frequency cepstral coefficients for a segment
    The very first MFCC, the 0th coefficient, does not convey information relevant to the overall shape of the spectrum. 
    It only conveys a constant offset, i.e. adding a constant value to the entire spectrum. We discard it.
    BE SURE TO NORMALIZE
    
    Parameters:
        segment: numpy array, a time series of audio data
        sr: int, sampling rate, default 22050
        n_mfcc: int, the number of cepstral coefficients to return, default 20.
    Returns:
        numpy array of shape (n_mfcc - 1,)
    '''
    if (len(segment) != 0):
        components = librosa.feature.mfcc(y=segment,sr=sr, n_mfcc=n_mfcc ) # return shape (n_mfcc, # frames)

        return np.mean(components[1:], axis=1)


def zero_crossing_rate(segment):
    '''
    Get average zero crossing rate for a segment. Add a small constant to the signal to negate small amount of noise near silent
    periods.
    
    Parameters:
        segment: numpy array, a time series of audio data
    Returns:
        float, average zero crossing rate for the given segment
    '''
   

    rate_vector = librosa.feature.zero_crossing_rate(segment+ 0.0001, frame_length=len(segment))[0] # returns array with shape (1,x)
    return np.mean(rate_vector)


def avg_spectral_centroid(segment, sr=22050):
    '''
    Indicate at which frequency the energy is centered on. Like a weighted mean, weighting avg frequency by the energy.
    Add small constant to audio signal to discard noise from silence
    Parameters:
        segment: numpy array, a time series of audio data
        sr: int, sampling rate
    Returns:
        float, the average frequency which the energy is centered on.
    '''
    centroid = librosa.feature.spectral_centroid(segment+0.01, sr=sr)[0]
    return np.mean(centroid)


def avg_spectral_contrast(segment, sr=22050, n_bands=6):
    '''
    considers the spectral peak, the spectral valley, and their difference in each frequency subband
    
    columns correspond to a spectral band
    
    average contrast : np.ndarray [shape=(n_bands + 1)]
    each row of spectral contrast values corresponds to a given
    octave-based frequency, take average across bands
    
    '''
    contr = librosa.feature.spectral_contrast(segment, sr=sr, n_bands=n_bands)
    return np.mean(contr, axis=1) # take average across bands

# %%
song = all_songs[-1]

# %%
features = []
i = 0
for segment in song:
    print "segment #: {}, shape: {}".format(i, segment.shape)
    feature_vector = get_features(segment)
    features.append(feature_vector)
    i += 1
all_feature_vector = np.array(features)
n_seg = all_feature_vector.shape[0]
feature_length = all_feature_vector[0].shape[0]
all_feature_vector = np.reshape(all_feature_vector, (all_feature_vector.shape[0], fea))
# Out:
# segment #: 0, shape: (1536,)
# segment #: 1, shape: (5632,)
# segment #: 2, shape: (5632,)
# segment #: 3, shape: (6144,)
# segment #: 4, shape: (5120,)
# segment #: 5, shape: (6144,)
# segment #: 6, shape: (4096,)
# segment #: 7, shape: (7680,)
# segment #: 8, shape: (4608,)
# segment #: 9, shape: (2560,)
# segment #: 10, shape: (9728,)
# segment #: 11, shape: (5632,)
# segment #: 12, shape: (5632,)
# segment #: 13, shape: (6144,)
# segment #: 14, shape: (4096,)
# segment #: 15, shape: (7168,)
# segment #: 16, shape: (4608,)
# segment #: 17, shape: (6656,)
# segment #: 18, shape: (6144,)
# segment #: 19, shape: (5120,)
# segment #: 20, shape: (6656,)
# segment #: 21, shape: (4096,)
# segment #: 22, shape: (7168,)
# segment #: 23, shape: (4096,)
# segment #: 24, shape: (7168,)
# segment #: 25, shape: (5120,)
# segment #: 26, shape: (6656,)
# segment #: 27, shape: (4608,)
# segment #: 28, shape: (6144,)
# segment #: 29, shape: (4608,)
# segment #: 30, shape: (6656,)
# segment #: 31, shape: (6144,)
# segment #: 32, shape: (5120,)
# segment #: 33, shape: (6144,)
# segment #: 34, shape: (6144,)
# segment #: 35, shape: (5632,)
# segment #: 36, shape: (5632,)
# segment #: 37, shape: (5120,)
# segment #: 38, shape: (0,)
# segment #: 39, shape: (6144,)
# segment #: 40, shape: (5632,)
# segment #: 41, shape: (0,)
# segment #: 42, shape: (6144,)
# segment #: 43, shape: (3584,)
# segment #: 44, shape: (0,)
# segment #: 45, shape: (8192,)
# segment #: 46, shape: (4096,)
# segment #: 47, shape: (6656,)
# segment #: 48, shape: (4608,)
# segment #: 49, shape: (7168,)
# segment #: 50, shape: (4608,)
# segment #: 51, shape: (6144,)
# segment #: 52, shape: (7168,)
# segment #: 53, shape: (11264,)
# segment #: 54, shape: (8192,)
# segment #: 55, shape: (9216,)
# segment #: 56, shape: (2560,)
# segment #: 57, shape: (13824,)
# segment #: 58, shape: (4608,)
# segment #: 59, shape: (7168,)
# segment #: 60, shape: (4608,)
# segment #: 61, shape: (1536,)
# segment #: 62, shape: (4608,)
# segment #: 63, shape: (1536,)
# segment #: 64, shape: (5120,)
# segment #: 65, shape: (5632,)
# segment #: 66, shape: (5120,)
# segment #: 67, shape: (6144,)
# segment #: 68, shape: (4096,)
# segment #: 69, shape: (7680,)
# segment #: 70, shape: (5632,)
# segment #: 71, shape: (6144,)
# segment #: 72, shape: (4608,)
# segment #: 73, shape: (6656,)
# segment #: 74, shape: (11776,)
# segment #: 75, shape: (4608,)
# segment #: 76, shape: (5632,)
# segment #: 77, shape: (11264,)
# segment #: 78, shape: (7680,)
# segment #: 79, shape: (8704,)
# segment #: 80, shape: (7680,)
# segment #: 81, shape: (6144,)
# segment #: 82, shape: (2560,)
# segment #: 83, shape: (12800,)
# segment #: 84, shape: (7680,)
# segment #: 85, shape: (3584,)
# segment #: 86, shape: (6656,)
# segment #: 87, shape: (5632,)
# segment #: 88, shape: (7168,)
# segment #: 89, shape: (4608,)
# segment #: 90, shape: (6656,)
# segment #: 91, shape: (4608,)
# segment #: 92, shape: (5632,)
# segment #: 93, shape: (6144,)
# segment #: 94, shape: (6144,)
# segment #: 95, shape: (5632,)
# segment #: 96, shape: (7168,)
# segment #: 97, shape: (4608,)
# segment #: 98, shape: (6144,)
# segment #: 99, shape: (4096,)
# segment #: 100, shape: (6144,)
# segment #: 101, shape: (6144,)
# segment #: 102, shape: (10752,)
# segment #: 103, shape: (6656,)
# segment #: 104, shape: (3072,)
# segment #: 105, shape: (8192,)
# segment #: 106, shape: (6144,)
# segment #: 107, shape: (5632,)
# segment #: 108, shape: (5632,)
# segment #: 109, shape: (6144,)
# segment #: 110, shape: (6144,)
# segment #: 111, shape: (5632,)
# segment #: 112, shape: (4096,)
# segment #: 113, shape: (5632,)
# segment #: 114, shape: (7168,)
# segment #: 115, shape: (5120,)
# segment #: 116, shape: (6656,)
# segment #: 117, shape: (6144,)
# segment #: 118, shape: (4096,)
# segment #: 119, shape: (7168,)
# segment #: 120, shape: (4096,)
# segment #: 121, shape: (6656,)
# segment #: 122, shape: (6144,)
# segment #: 123, shape: (4608,)
# segment #: 124, shape: (5120,)
# segment #: 125, shape: (13312,)
# segment #: 126, shape: (5120,)
# segment #: 127, shape: (5120,)
# segment #: 128, shape: (7680,)
# segment #: 129, shape: (4096,)
# segment #: 130, shape: (0,)
# segment #: 131, shape: (6656,)
# segment #: 132, shape: (5120,)
# segment #: 133, shape: (5632,)
# segment #: 134, shape: (3072,)
# segment #: 135, shape: (0,)
# segment #: 136, shape: (9728,)
# segment #: 137, shape: (4096,)
# segment #: 138, shape: (5632,)
# segment #: 139, shape: (6144,)
# segment #: 140, shape: (6144,)
# segment #: 141, shape: (5632,)
# segment #: 142, shape: (5632,)
# segment #: 143, shape: (5120,)
# segment #: 144, shape: (6656,)
# segment #: 145, shape: (3072,)
# segment #: 146, shape: (3072,)
# segment #: 147, shape: (4608,)
# segment #: 148, shape: (5120,)
# segment #: 149, shape: (4608,)
# segment #: 150, shape: (2560,)
# segment #: 151, shape: (3072,)
# segment #: 152, shape: (2560,)
# segment #: 153, shape: (3072,)
# segment #: 154, shape: (7168,)
# segment #: 155, shape: (0,)
# segment #: 156, shape: (6656,)
# segment #: 157, shape: (6144,)
# segment #: 158, shape: (5120,)
# segment #: 159, shape: (1536,)
# segment #: 160, shape: (4096,)
# segment #: 161, shape: (6656,)
# segment #: 162, shape: (3072,)
# segment #: 163, shape: (3072,)
# segment #: 164, shape: (11264,)
# segment #: 165, shape: (6144,)
# segment #: 166, shape: (2560,)
# segment #: 167, shape: (9216,)
# segment #: 168, shape: (3584,)
# segment #: 169, shape: (0,)
# segment #: 170, shape: (5120,)
# segment #: 171, shape: (2048,)
# segment #: 172, shape: (2560,)
# segment #: 173, shape: (3072,)
# segment #: 174, shape: (5632,)
# segment #: 175, shape: (2560,)
# segment #: 176, shape: (8192,)
# segment #: 177, shape: (6144,)
# segment #: 178, shape: (5632,)
# segment #: 179, shape: (4608,)
# segment #: 180, shape: (7680,)
# segment #: 181, shape: (2048,)
# segment #: 182, shape: (14336,)
# segment #: 183, shape: (6144,)
# segment #: 184, shape: (6144,)
# segment #: 185, shape: (4608,)
# segment #: 186, shape: (6144,)
# segment #: 187, shape: (6144,)
# segment #: 188, shape: (6656,)
# segment #: 189, shape: (10752,)
# segment #: 190, shape: (5120,)
# segment #: 191, shape: (7168,)
# segment #: 192, shape: (10752,)
# segment #: 193, shape: (4096,)
# segment #: 194, shape: (6144,)
# segment #: 195, shape: (12800,)
# segment #: 196, shape: (4096,)
# segment #: 197, shape: (7680,)
# segment #: 198, shape: (5120,)
# segment #: 199, shape: (11264,)
# segment #: 200, shape: (6144,)
# segment #: 201, shape: (11776,)
# segment #: 202, shape: (5632,)
# segment #: 203, shape: (5632,)
# segment #: 204, shape: (5120,)
# segment #: 205, shape: (5632,)
# segment #: 206, shape: (6144,)
# segment #: 207, shape: (3072,)
# segment #: 208, shape: (6656,)
# segment #: 209, shape: (5632,)
# segment #: 210, shape: (8192,)
# segment #: 211, shape: (10752,)
# segment #: 212, shape: (6656,)
# segment #: 213, shape: (5120,)
# segment #: 214, shape: (6144,)
# segment #: 215, shape: (5632,)
# segment #: 216, shape: (11264,)
# segment #: 217, shape: (11776,)
# segment #: 218, shape: (4608,)
# segment #: 219, shape: (6656,)
# segment #: 220, shape: (5632,)
# segment #: 221, shape: (16384,)
# segment #: 222, shape: (7168,)
# segment #: 223, shape: (11776,)
# segment #: 224, shape: (5632,)
# segment #: 225, shape: (3584,)
# segment #: 226, shape: (13312,)
# segment #: 227, shape: (6144,)
# segment #: 228, shape: (5120,)
# segment #: 229, shape: (16896,)
# segment #: 230, shape: (17920,)
# segment #: 231, shape: (5120,)
# segment #: 232, shape: (6144,)
# segment #: 233, shape: (4608,)
# segment #: 234, shape: (6656,)
# segment #: 235, shape: (6144,)
# segment #: 236, shape: (5632,)
# segment #: 237, shape: (10240,)
# segment #: 238, shape: (6144,)
# segment #: 239, shape: (12288,)
# segment #: 240, shape: (10752,)
# segment #: 241, shape: (10752,)
# segment #: 242, shape: (6144,)
# segment #: 243, shape: (3072,)
# segment #: 244, shape: (2560,)
# segment #: 245, shape: (6656,)
# segment #: 246, shape: (5120,)
# segment #: 247, shape: (6656,)
# segment #: 248, shape: (4608,)
# segment #: 249, shape: (6656,)
# segment #: 250, shape: (6144,)
# segment #: 251, shape: (4096,)
# segment #: 252, shape: (7168,)
# segment #: 253, shape: (5120,)
# segment #: 254, shape: (5120,)
# segment #: 255, shape: (7168,)
# segment #: 256, shape: (5120,)
# segment #: 257, shape: (11264,)
# segment #: 258, shape: (12288,)
# segment #: 259, shape: (2048,)
# segment #: 260, shape: (8704,)
# segment #: 261, shape: (5632,)
# segment #: 262, shape: (6144,)
# segment #: 263, shape: (2560,)
# segment #: 264, shape: (14848,)
# segment #: 265, shape: (6144,)
# segment #: 266, shape: (5120,)
# segment #: 267, shape: (5120,)
# segment #: 268, shape: (6656,)
# segment #: 269, shape: (6144,)
# segment #: 270, shape: (3072,)
# segment #: 271, shape: (19968,)
# segment #: 272, shape: (10752,)
# segment #: 273, shape: (6144,)
# segment #: 274, shape: (5632,)
# segment #: 275, shape: (3072,)
# segment #: 276, shape: (13312,)
# segment #: 277, shape: (6144,)
# segment #: 278, shape: (6656,)
# segment #: 279, shape: (16384,)
# segment #: 280, shape: (3072,)
# segment #: 281, shape: (5632,)
# segment #: 282, shape: (14336,)
# segment #: 283, shape: (23552,)
# segment #: 284, shape: (22016,)
# segment #: 285, shape: (12288,)
# segment #: 286, shape: (10752,)
# segment #: 287, shape: (12288,)
# segment #: 288, shape: (10240,)
# segment #: 289, shape: (12800,)
# segment #: 290, shape: (10752,)
# segment #: 291, shape: (11776,)
# segment #: 292, shape: (10752,)
# segment #: 293, shape: (12800,)
# segment #: 294, shape: (10752,)
# segment #: 295, shape: (22528,)
# segment #: 296, shape: (12288,)
# segment #: 297, shape: (5632,)
# segment #: 298, shape: (6144,)
# segment #: 299, shape: (5120,)
# segment #: 300, shape: (5120,)
# segment #: 301, shape: (6656,)
# segment #: 302, shape: (5120,)
# segment #: 303, shape: (12288,)
# segment #: 304, shape: (11264,)
# segment #: 305, shape: (11264,)
# segment #: 306, shape: (11264,)
# segment #: 307, shape: (11776,)
# segment #: 308, shape: (4096,)
# segment #: 309, shape: (5632,)
# segment #: 310, shape: (4096,)
# segment #: 311, shape: (8704,)
# segment #: 312, shape: (11776,)
# segment #: 313, shape: (10752,)
# segment #: 314, shape: (11776,)
# segment #: 315, shape: (10752,)
# segment #: 316, shape: (12288,)
# segment #: 317, shape: (11264,)
# segment #: 318, shape: (12288,)
# segment #: 319, shape: (11264,)
# segment #: 320, shape: (10752,)
# segment #: 321, shape: (12288,)
# segment #: 322, shape: (11264,)
# segment #: 323, shape: (10752,)
# segment #: 324, shape: (12288,)
# segment #: 325, shape: (11264,)
# segment #: 326, shape: (11264,)
# segment #: 327, shape: (23040,)
# segment #: 328, shape: (22016,)
# segment #: 329, shape: (23552,)
# segment #: 330, shape: (11776,)
# segment #: 331, shape: (6144,)
# segment #: 332, shape: (5632,)
# segment #: 333, shape: (9728,)
# segment #: 334, shape: (7680,)
# segment #: 335, shape: (5120,)
# segment #: 336, shape: (10752,)
# segment #: 337, shape: (11776,)
# segment #: 338, shape: (23040,)
# segment #: 339, shape: (11264,)
# segment #: 340, shape: (12288,)
# segment #: 341, shape: (10752,)
# segment #: 342, shape: (6656,)
# segment #: 343, shape: (6144,)
# segment #: 344, shape: (10752,)
# segment #: 345, shape: (2560,)
# segment #: 346, shape: (9216,)
# segment #: 347, shape: (4608,)
# segment #: 348, shape: (17920,)
# segment #: 349, shape: (5632,)
# segment #: 350, shape: (11264,)
# segment #: 351, shape: (6144,)
# segment #: 352, shape: (5120,)
# segment #: 353, shape: (6656,)
# segment #: 354, shape: (6144,)
# segment #: 355, shape: (5632,)
# segment #: 356, shape: (5632,)
# segment #: 357, shape: (16384,)
# segment #: 358, shape: (23040,)
# segment #: 359, shape: (12288,)
# segment #: 360, shape: (10752,)
# segment #: 361, shape: (11776,)
# segment #: 362, shape: (5632,)
# segment #: 363, shape: (6144,)
# segment #: 364, shape: (4096,)
# segment #: 365, shape: (6656,)
# segment #: 366, shape: (6144,)
# segment #: 367, shape: (5632,)
# segment #: 368, shape: (12288,)
# segment #: 369, shape: (4608,)
# segment #: 370, shape: (6144,)
# segment #: 371, shape: (22528,)
# segment #: 372, shape: (6656,)
# segment #: 373, shape: (5632,)
# segment #: 374, shape: (5632,)
# segment #: 375, shape: (5632,)
# segment #: 376, shape: (6144,)
# segment #: 377, shape: (17920,)
# segment #: 378, shape: (10752,)
# segment #: 379, shape: (12288,)
# segment #: 380, shape: (23040,)
# segment #: 381, shape: (5632,)
# segment #: 382, shape: (5120,)
# segment #: 383, shape: (11776,)
# segment #: 384, shape: (6144,)
# segment #: 385, shape: (5120,)
# segment #: 386, shape: (6656,)
# segment #: 387, shape: (5632,)
# segment #: 388, shape: (5120,)
# segment #: 389, shape: (5632,)
# segment #: 390, shape: (5632,)
# segment #: 391, shape: (6144,)
# segment #: 392, shape: (10752,)
# segment #: 393, shape: (11264,)
# segment #: 394, shape: (11776,)
# segment #: 395, shape: (5632,)
# segment #: 396, shape: (5632,)
# segment #: 397, shape: (11264,)
# segment #: 398, shape: (12288,)
# segment #: 399, shape: (10752,)
# segment #: 400, shape: (9728,)
# segment #: 401, shape: (3584,)
# segment #: 402, shape: (22016,)
# segment #: 403, shape: (11264,)
# segment #: 404, shape: (5120,)
# segment #: 405, shape: (7168,)
# segment #: 406, shape: (4608,)
# segment #: 407, shape: (6656,)
# segment #: 408, shape: (5632,)
# segment #: 409, shape: (6144,)
# segment #: 410, shape: (10240,)
# segment #: 411, shape: (13824,)
# segment #: 412, shape: (32256,)
# segment #: 413, shape: (11776,)
# segment #: 414, shape: (8192,)
# segment #: 415, shape: (14848,)
# segment #: 416, shape: (6144,)
# segment #: 417, shape: (3584,)
# segment #: 418, shape: (0,)
# segment #: 419, shape: (13824,)
# segment #: 420, shape: (11776,)
# segment #: 421, shape: (11264,)
# segment #: 422, shape: (10752,)
# segment #: 423, shape: (12288,)
# segment #: 424, shape: (10240,)
# segment #: 425, shape: (12288,)
# segment #: 426, shape: (12288,)
# segment #: 427, shape: (11264,)
# segment #: 428, shape: (11264,)
# segment #: 429, shape: (11264,)
# segment #: 430, shape: (11264,)
# segment #: 431, shape: (12288,)
# segment #: 432, shape: (11264,)
# segment #: 433, shape: (10752,)
# segment #: 434, shape: (9728,)
# segment #: 435, shape: (13824,)
# segment #: 436, shape: (5632,)
# segment #: 437, shape: (11776,)
# segment #: 438, shape: (3584,)
# segment #: 439, shape: (7168,)
# segment #: 440, shape: (6144,)
# segment #: 441, shape: (10752,)
# segment #: 442, shape: (11264,)
# segment #: 443, shape: (12800,)
# segment #: 444, shape: (23040,)
# segment #: 445, shape: (11264,)
# segment #: 446, shape: (5120,)
# segment #: 447, shape: (6144,)
# segment #: 448, shape: (10752,)
# segment #: 449, shape: (12288,)
# segment #: 450, shape: (10752,)
# segment #: 451, shape: (12288,)
# segment #: 452, shape: (10240,)
# segment #: 453, shape: (12288,)
# segment #: 454, shape: (22016,)
# segment #: 455, shape: (11776,)
# segment #: 456, shape: (12288,)
# segment #: 457, shape: (11776,)
# segment #: 458, shape: (9728,)
# segment #: 459, shape: (13824,)
# segment #: 460, shape: (10752,)
# segment #: 461, shape: (11776,)
# segment #: 462, shape: (11264,)
# segment #: 463, shape: (11264,)
# segment #: 464, shape: (5120,)
# segment #: 465, shape: (6656,)
# segment #: 466, shape: (8192,)
# segment #: 467, shape: (2048,)
# segment #: 468, shape: (10240,)
# segment #: 469, shape: (20480,)
# segment #: 470, shape: (172544,)
# segment #: 471, shape: (7364,)
# (472, 29)

# %%
np.reshape(all_feature_vector, (all_feature_vector.shape[0], all_feature_vector[0].shape[0]))
# Out:
# (472, 29)

# %%
feature_tuple= (avg_energy(song[0]), np.array([1,2,3]))
concat = [feat if type(feat) is np.ndarray else np.array([feat]) for feat in feature_tuple]
print concat
np.concatenate(concat)
# Out:
# [array([1.345684e-06], dtype=float32), array([1, 2, 3])]
# array([1.34568404e-06, 1.00000000e+00, 2.00000000e+00, 3.00000000e+00])

# %%
# Out:
# ()

# %%
zero_crossing_rate(song[50])
# Out:
# (10,)
# 0.04490017361111111

# %%
zero_crossing_rate(song[50])
# Out:
# (10,)
# 0.052490234375

# %%
avg_spectral_centroid(song[50][:2048])
# Out:
# (5,)
# [1748.16032803 1760.62026969 1701.48853693 1742.9214373  1786.03957456]
# 1747.84602930271

# %%
cent.shape
# Out:
# ()

# %%
cent
# Out:
# 1693.2882637712785

# %%
avg_spectral_centroid(song[50]).shape
# Out:
# (10,)

# %%
song[50][:2048]
# Out:
# array([-0.07319131, -0.1618235 , -0.13289955, ..., -0.08992862,
#        -0.10405801, -0.09187029], dtype=float32)

# %%
np.mean(avg_spectral_contrast(song[50]), axis = 1)
# Out:
# (7, 10)
# array([18.06604353, 18.43214227, 21.66997491, 16.20400406, 19.27938096,
#        21.40340924, 29.17569621])

# %%
avg_spectral_contrast(song[50])
# Out:
# (7, 10)
# array([20.57025634, 20.47953106, 20.78916248, 18.45730515, 19.12388027,
#        21.65153773, 22.16584386])

# %%
np.concatenate()
